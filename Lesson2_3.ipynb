# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
#строим график окружности
r=10
x0= 3
y0= 1

x=np.linspace(-r+x0, r+x0, 100)
y1=(r**2 - (x-x0)**2)**0.5 + y0
y2=-(r**2 - (x-x0)**2)**0.5 + y0
plt.xlabel("Ось Х")
plt.ylabel("Ось У")
plt.plot(x, y1, x, y2)
plt.gca().set_aspect('equal')

# %%
#строим график эллипса

a= 12
b= 5

x=np.linspace(-a, a, 1000)
y1 = ((1 - (x**2/a**2))*b**2)**0.5
y2 = -((1 - (x**2/a**2))*b**2)**0.5
plt.xlabel("Ось Х")
plt.ylabel("Ось У")
plt.plot(x, y1, x, y2)
plt.gca().set_aspect('equal')

# %%
#строим график гиперболы

a= 2
b= 6

x=np.linspace(-a*5, -a, 10000) + np.linspace(a, a*5, 10000)
y1 = (((x**2)/(a**2)-1)*(b**2))**0.5
y2 = -(((x**2/a**2)-1)*(b**2))**0.5
plt.xlabel("Ось Х")
plt.ylabel("Ось У")
plt.plot(x, y1, x, y2)
plt.gca().set_aspect('equal')
# Out:
# <ipython-input-4-f1b36598bbfc>:7: RuntimeWarning: invalid value encountered in sqrt
#   y1 = (((x**2)/(a**2)-1)*(b**2))**0.5
# <ipython-input-4-f1b36598bbfc>:8: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(((x**2/a**2)-1)*(b**2))**0.5
